# %% [markdown]
# <a href="https://colab.research.google.com/github/Jason43454/2026-Fall-305/blob/main/cost_behavior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cost Behavior Analysis
# ### Cost Accounting I - Riverbend Manufacturing
#
# We have 24 months of production and cost data.
# Our job is to work out how each cost behaves when the number of units produced changes.
#
# Cost driver (activity base): Units Produced

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/cost_behavior_data.csv')
# print("Rows and Columns:",df.shape) # displays number of rows
# display(df.head()) # Explore the top 5 lines of a spreadsheet
# display(df.tail()) # Explore the last 5 lines of a spreadsheet
# display(df.sample()) # Explore one row of the psreadsheet
# df  # Displays Everything
# print(df.info())
# display(df.describe()) # gives data like count mean std for the rows
display(df.iloc[9])
